# %% [markdown]
# # Titanic Dataset from Kaggle

# %% [markdown]
# ## 1. Basic Data Exploration

# %% [markdown]
# ### Load the dataset and display the first five rows.

# %%
import pandas as pd
df  = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Check the number of rows and columns in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Get the data types of each column.

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### Check for missing values and count them.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# ### Fill missing values in the "age" column with the median age.

# %%
median = df["Age"].median()
df["Age"].fillna(median, inplace=True)
df["Age"]
# Out:
# C:\Users\Abdul Ahad\AppData\Local\Temp\ipykernel_1456\471013940.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(median, inplace=True)
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# ### Drop the "cabin" column (since it has many missing values).

# %%
df.drop(columns="Cabin", inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Replace missing values in "embark_town" with the most frequent value.

# %%
most_freq_value = df["Embarked"].value_counts().idxmax()
df["Embarked"].fillna(most_freq_value, inplace=True)
df
# Out:
# C:\Users\Abdul Ahad\AppData\Local\Temp\ipykernel_1456\3642867828.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Embarked"].fillna(most_freq_value, inplace=True)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# ...

# %% [markdown]
# ## 3. Data Selection & Filtering

# %% [markdown]
# ### Select only passengers who are males and above 30 years old.

# %%
df[(df["Sex"] == 'male') & (df["Age"] > 30)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 4              5         0       3              Allen, Mr. William Henry
# 6              7         0       1               McCarthy, Mr. Timothy J
# 13            14         0       3           Andersson, Mr. Anders Johan
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# ..           ...       ...     ...                                   ...
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 873          874         0       3           Vander Cruyssen, Mr. Victor
# 881          882         0       3                    Markun, Mr. Johann
# 890          891         0       3                   Dooley, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Embarked
# ...

# %% [markdown]
# ### Display only "name", "age", and "fare" columns for passengers who survived.

# %%
df[df["Survived"]  == 1 ][["Name" ,"Age", "Fare"]]
# Out:
#                                                   Name   Age     Fare
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.1000
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  11.1333
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0  30.0708
# ..                                                 ...   ...      ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0   7.2250
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0  83.1583
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0  26.0000
# 887                       Graham, Miss. Margaret Edith  19.0  30.0000
# 889                              Behr, Mr. Karl Howell  26.0  30.0000
#
# [342 rows x 3 columns]

# %% [markdown]
# ### Find all passengers who paid a fare greater than 100.

# %%
df[df["Fare"] > 100]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %% [markdown]
# ## 4. Aggregation & Grouping

# %% [markdown]
# ### Find the average fare paid by each class.

# %%
df.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# ### Count the number of passengers based on their embarkation town.

# %%
number_of_passengers = df["Embarked"].value_counts()
number_of_passengers
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# ### Find the maximum age of passengers in each gender category.

# %%
df.groupby("Sex")["Age"].max()
# Out:
# Sex
# female    63.0
# male      80.0
# Name: Age, dtype: float64

# %% [markdown]
# ## 5. Sorting & Ranking

# %% [markdown]
# ### Sort the dataset based on "age" in descending order.

# %%
df.sort_values(by="Age", ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 831          832         1       2       Richards, Master. George Sibley
# 469          470         1       3         Baclini, Miss. Helene Barbara
# 644          645         1       3                Baclini, Miss. Eugenie
# 755          756         1       2             Hamalainen, Master. Viljo
# 803          804         1       3       Thomas, Master. Assad Alexander
#
#         Sex    Age  SibSp  Parch    Ticket     Fare Embarked
# ...

# %% [markdown]
# ### Sort based on "fare" first (descending) and then by "age" (ascending).

# %%
df.sort_values(by=["Fare" , "Age"], ascending=[False, True])
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 88            89         1       1          Fortune, Miss. Mabel Helen
# ..           ...       ...     ...                                 ...
# 179          180         0       3                 Leonard, Mr. Lionel
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 263          264         0       1               Harrison, Mr. William
# 597          598         0       3                 Johnson, Mr. Alfred
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Embarked
# ...

# %% [markdown]
# ## 6. Data Visualization (Using Pandas or Seaborn)

# %% [markdown]
# ### Plot a bar chart showing the number of survivors by gender.

# %%
import matplotlib.pyplot as plt 

survivors_by_gender = df[df["Survived"] == 1]["Sex"].value_counts()
survivors_by_gender.plot(kind="bar", color=["pink", "skyblue"])
plt.title("Number of Survivers by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of survivers")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Create a histogram of the age distribution.

# %%
plt.hist(df["Age"], color="lightgreen", )
plt.xlabel("Ages", )
plt.ylabel("Number of people")
plt.show()

# %% [markdown]
# ### Generate a box plot to see the distribution of fare by passenger class.

# %%
df.boxplot(column="Fare" , by="Pclass")
plt.xlabel("Passenger Class")
plt.ylabel("Fare")
plt.title("Distribution of Fare by Passenger Class")
plt.suptitle("")
plt.show()
