# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#
# File c:\Users\Abdul Ahad\anaconda3\Lib\site-packages\seaborn\__init__.py:2
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File c:\Users\Abdul Ahad\anaconda3\Lib\site-packages\seaborn\rcmod.py:3
#       1 """Control plot style and scaling using the matplotlib rcParams interface."""
#       2 import functools
# ----> 3 import matplotlib as mpl
#       4 from cycler import cycler
#       5 from . import palettes
#
# File c:\Users\Abdul Ahad\anaconda3\Lib\site-packages\matplotlib\__init__.py:159
#     155 from packaging.version import parse as parse_version
# ...
