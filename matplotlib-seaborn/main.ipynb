# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.scatter(df["total_bill"], df["tip"], c="red")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Scatter plot of total bill vs Tips")
plt.show()

# %%
colors = {'Male': 'blue', 'Female': 'pink'}

plt.scatter(df["total_bill"], df["tip"], c=df["sex"].map(colors))
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Scatter plot of total bill vs Tips")
plt.show()

# %%
# Generate x values from 0 to 2π
x = np.linspace(0, 2 * np.pi, 100)

# Compute sine and cosine values
y_sin = np.sin(x)
y_cos = np.cos(x)

# First subplot: Sine wave
plt.subplot(1,2,1)
plt.plot(x, y_sin)
plt.title("Line Plot of Sine Wave")
plt.xlabel("x (radians)")
plt.ylabel("sin(x)")
plt.grid(True)

# Second subplot: Cosine wave
plt.subplot(1,2,2)
plt.plot(x, y_cos)
plt.title("Line Plot of Cosine Wave")
plt.xlabel("x (radians)")
plt.ylabel("cos(x)")
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
df.groupby(df['day'])
# Out:
# C:\Users\Abdul Ahad\AppData\Local\Temp\ipykernel_15424\2563004300.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(df['day'])
